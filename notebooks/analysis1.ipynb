# %% [markdown]
# # Data Analysis

# %% [markdown]
# This notebook includes all actions to describe the data (i.e. key statistics, etc).<br>
# **Data**: CSV saved in '../data/raw/rawdata.csv. This file contains all updated tweets (old and new) as per 'acquisition module'

# %% [markdown]
# **Key actions**
# <br> <hr>
# - Identify and remove duplicate records
# - Identify and remove Tweets done by user = BiciMAD
# - Examine data for potential issues
# - Identify and fill in missing values
# - *Remove low variance columns (potentially not needed)*
# - Identify potential outliers *(potentially not needed)*
# - Correct incorrect data types *(potentially only text variable)*
# - Remove special characters and clean categorical variables *(potentially only text variable)*
# <br>

# %% [markdown]
# ## 1. Read & clean data

# %% [markdown]
# #### 1.1 Read data
# <hr>

# %%
# all modules
import pandas as pd
# if packaches need upload 
# pip install --upgrade pip

# %%
# load dataset
data = pd.read_csv('../data/raw/rawdata.csv')

# %%
# select required columns
data = data.drop(columns =['Unnamed: 0'])

# %%
data.shape
# Out:
# (8874, 4)

# %%
# data.dtypes

# %%
# data.head(5)

# %% [markdown]
# #### 1.2 Clean data
# <hr>

# %%
# change date type from 'object' to 'date'
data['date'] = pd.to_datetime(data['date'])

# %%
# data.dtypes

# %%
data.isnull().sum()
# Out:
# date         0
# id           0
# text         0
# user_name    0
# dtype: int64

# %%
# count duplicates 'id' to be sure
len(data['id'])-len(data['id'].drop_duplicates())
# Out:
# 0

# %%
data.isnull().sum()
# Out:
# date         0
# id           0
# text         0
# user_name    0
# dtype: int64

# %%
# data['id'].describe()

# %%
# drop duplicates
data.drop_duplicates(subset=['id'],keep='last', inplace= True)

# %%
data.shape
# Out:
# (8874, 4)

# %% [markdown]
# #### 1.3 Take out BiciMad Tweets
# <hr>

# %%
# data analysis => sorting
data = data.sort_values('user_name', ascending=False)

# %%
data['user_name'].value_counts()
# Out:
# BiciMAD                181
# BICIMAD EN LUCHA       147
# ErBoteRojo             145
# Jesús García Diaz      140
# Plataforma Sindical    128
#                       ...
# RG                       1
# jj                       1
# Pablo Rivas              1
# LA ESPERANZA❤CRECE       1
# Bego CL                  1
# Name: user_name, Length: 3594, dtype: int64

# %%
data = data[data.user_name != 'BiciMAD']

# %%
data.columns
# Out:
# Index(['date', 'id', 'text', 'user_name'], dtype='object')

# %% [markdown]
# ## 2. Explore data

# %% [markdown]
# #### 2.1 Sort values by 'date' and reset index
# <hr>

# %%
data = data.sort_values(by ='date', ascending=True)

# %%
data = data.reset_index()

# %%
data = data.drop(columns =['index'])

# %%
data.tail(20)
# Out:
#                     date                   id  \
# 8673 2020-10-23 10:57:08  1319593695839223810
# 8674 2020-10-23 10:58:47  1319594110144204801
# 8675 2020-10-23 11:06:13  1319595980975648769
# 8676 2020-10-23 11:19:16  1319599263979024389
# 8677 2020-10-23 11:21:19  1319599779979186176
# 8678 2020-10-23 11:21:30  1319599828742119426
# 8679 2020-10-23 11:21:35  1319599849373863937
# 8680 2020-10-23 11:21:44  1319599886959054848
# 8681 2020-10-23 11:22:27  1319600066546597888
# 8682 2020-10-23 11:24:28  1319600576091574272
# 8683 2020-10-23 11:26:57  1319601198765363200
# 8684 2020-10-23 11:27:12  1319601262975909893
# 8685 2020-10-23 11:28:08  1319601494841327616
# 8686 2020-10-23 11:28:19  1319601542501224448
# 8687 2020-10-23 11:28:27  1319601575778811904
# 8688 2020-10-23 11:29:32  1319601848693739520
# 8689 2020-10-23 11:31:01  1319602221357596675
# 8690 2020-10-23 11:31:22  1319602309316382721
# 8691 2020-10-23 11:32:20  1319602554146357251
# 8692 2020-10-23 11:44:42  1319605665401360385
#
#                                                    text  \
# 8673  RT @ignprados: Hola, @BiciMAD, hoy a las 9:10 ...
# 8674        @BiciMAD en Latina🥰 https://t.co/TtvpUOO5dw
# 8675  RT @PlataformaEMT: Cientos de bicicletas de @B...
# 8676  RT @PlataformaEMT: Buenos días plataformer@s.\...
# 8677  RT @carmartinco: La 204 de nuevo, @BiciMAD sup...
# 8678  RT @diego_rebollo: Esta es la realidad de @Bic...
# 8679  RT @PlataformaEMT: Buenos días plataformer@s.\...
# 8680  RT @PlataformaEMT: Cientos de bicicletas de @B...
# 8681  RT @MomoChan_says: @BiciMAD estación 42 con 6 ...
# 8682  RT @PlataformaEMT: Buenos días plataformer@s.\...
# 8683  RT @diego_rebollo: Esta es la realidad de @Bic...
# 8684  RT @carmartinco: La 204 de nuevo, @BiciMAD sup...
# 8685  RT @PlataformaEMT: Buenos días plataformer@s.\...
# 8686  RT @PlataformaEMT: Cientos de bicicletas de @B...
# 8687  La colaboración público privada de los gobiern...
# 8688  RT @PlataformaEMT: Buenos días plataformer@s.\...
# 8689  RT @PlataformaEMT: La colaboración público pri...
# 8690  RT @PlataformaEMT: La colaboración público pri...
# 8691  RT @verdechamberi: Para no perderse el seguimi...
# 8692  RT @PlataformaEMT: La colaboración público pri...
#
#                              user_name
# 8673                          Alberto.
# 8674  🏳️‍🌈🇪🇸 (🛴DEJA EL COCHE EN CASA🚲)
# 8675                               Jbp
# 8676                      jason adonis
# 8677                 Jesús García Diaz
# 8678                 Jesús García Diaz
# 8679                 Jesús García Diaz
# 8680                 Jesús García Diaz
# 8681                 Jesús García Diaz
# 8682                       Nomientas28
# 8683                              Javi
# 8684                              Javi
# 8685                              Javi
# 8686                              Javi
# 8687               Plataforma Sindical
# 8688               Plataforma Sindical
# 8689                        Marcos_HTZ
# 8690                               Jbp
# 8691                     Gonzalo Lopez
# 8692                       Trotamundos

# %% [markdown]
# #### 2.2 Check most recent tweets from users
# <hr>

# %%
# getting today's Timestamp
today = pd.Timestamp.today().floor('D')
# .normalize() does the same thing

# %%
today
# Out:
# Timestamp('2020-10-23 00:00:00')

# %%
data_today = data[(data['date'] > today )]

# %%
data_past = data[(data['date'] < today )]

# %%
data_past.shape[0]
# Out:
# 8543

# %%
data_today.shape[0]
# Out:
# 150

# %%
data_today
# Out:
#                     date                   id  \
# 8543 2020-10-23 00:02:23  1319428924116434944
# 8544 2020-10-23 00:11:28  1319431206086332419
# 8545 2020-10-23 00:13:54  1319431821067694082
# 8546 2020-10-23 01:03:15  1319444240099934208
# 8547 2020-10-23 02:26:26  1319465173086818305
# ...                  ...                  ...
# 8688 2020-10-23 11:29:32  1319601848693739520
# 8689 2020-10-23 11:31:01  1319602221357596675
# 8690 2020-10-23 11:31:22  1319602309316382721
# 8691 2020-10-23 11:32:20  1319602554146357251
# 8692 2020-10-23 11:44:42  1319605665401360385
#
#                                                    text  \
# 8543  RT @Esther_Gomez_M: Parece que @EMTmadrid pref...
# 8544  RT @edugaresp: El servicio de alquiler de bici...
# 8545  RT @Esther_Gomez_M: Prometió @AlmeidaPP_ 50 nu...
# 8546  RT @Esther_Gomez_M: Para conocer la difícil si...
# 8547  RT @Rita_Maestre: La foto que resume lo que ha...
# ...                                                 ...
# 8688  RT @PlataformaEMT: Buenos días plataformer@s.\...
# 8689  RT @PlataformaEMT: La colaboración público pri...
# 8690  RT @PlataformaEMT: La colaboración público pri...
# 8691  RT @verdechamberi: Para no perderse el seguimi...
# 8692  RT @PlataformaEMT: La colaboración público pri...
#
#                     user_name
# 8543     Ana Moradillo Alonso
# 8544  antonio 🏳️‍🌈antonio MAD
# 8545                     Kike
# 8546                    Rober
# 8547            Dani Aparicio
# ...                       ...
# 8688      Plataforma Sindical
# 8689               Marcos_HTZ
# 8690                      Jbp
# 8691            Gonzalo Lopez
# 8692              Trotamundos
#
# [150 rows x 4 columns]

# %%
# data.loc[data['user_name'] == 'Blanca Fernandez']

# %%
# Sacar subsets
# data_subset = data[data['user_name'].isin(['Blanca Fenrandez', 'BICIMAD EN LUCHA'])]

# %%
# data_subset

# %%
# First tweet available date
# data['date'].min()

# %%
# Most recent tweet date
# data['date'].max()

# %%
# saving data
# data.to_csv('../data/processed/data.csv', index=False)

# %% [markdown]
# ## 3. Sentiment analysis

# %% [markdown]
# #### 3.1 Prepare text
# <hr>

# %%
import re

# %% [markdown]
# ##### Ver que hacer con las 'ñ'
# <hr>

# %%
def clean_tweet(tweet):
    return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)", " ", tweet).split())
    #return " ".join(re.sub("([^0-9A-Za-z \t])|(\w+:\/\/\S+)", "", tweet).split())

# %%
data_today_clean_tweet = data_today.copy()

# %%
# Updated the tweets_clean 
data_today_clean_tweet['tweets_clean'] = data_today['text'].apply(clean_tweet)

# %%
# Print the updated dataframe 
data_today_clean_tweet
# Out:
#                     date                   id  \
# 8543 2020-10-23 00:02:23  1319428924116434944
# 8544 2020-10-23 00:11:28  1319431206086332419
# 8545 2020-10-23 00:13:54  1319431821067694082
# 8546 2020-10-23 01:03:15  1319444240099934208
# 8547 2020-10-23 02:26:26  1319465173086818305
# ...                  ...                  ...
# 8688 2020-10-23 11:29:32  1319601848693739520
# 8689 2020-10-23 11:31:01  1319602221357596675
# 8690 2020-10-23 11:31:22  1319602309316382721
# 8691 2020-10-23 11:32:20  1319602554146357251
# 8692 2020-10-23 11:44:42  1319605665401360385
#
#                                                    text  \
# 8543  RT @Esther_Gomez_M: Parece que @EMTmadrid pref...
# 8544  RT @edugaresp: El servicio de alquiler de bici...
# 8545  RT @Esther_Gomez_M: Prometió @AlmeidaPP_ 50 nu...
# 8546  RT @Esther_Gomez_M: Para conocer la difícil si...
# 8547  RT @Rita_Maestre: La foto que resume lo que ha...
# ...                                                 ...
# 8688  RT @PlataformaEMT: Buenos días plataformer@s.\...
# 8689  RT @PlataformaEMT: La colaboración público pri...
# 8690  RT @PlataformaEMT: La colaboración público pri...
# 8691  RT @verdechamberi: Para no perderse el seguimi...
# 8692  RT @PlataformaEMT: La colaboración público pri...
#
#                     user_name  \
# 8543     Ana Moradillo Alonso
# 8544  antonio 🏳️‍🌈antonio MAD
# 8545                     Kike
# 8546                    Rober
# 8547            Dani Aparicio
# ...                       ...
# 8688      Plataforma Sindical
# 8689               Marcos_HTZ
# 8690                      Jbp
# 8691            Gonzalo Lopez
# 8692              Trotamundos
#
#                                            tweets_clean
# 8543  RT Gomez M Parece que prefiere usar bicicletas...
# 8544  RT El servicio de alquiler de bicicletas de Ma...
# 8545  RT Gomez M Prometi 50 nuevas estaciones de est...
# 8546  RT Gomez M Para conocer la dif cil situaci n d...
# 8547  RT Maestre La foto que resume lo que ha hecho ...
# ...                                                 ...
# 8688  RT Buenos d as plataformer y contin an infland...
# 8689  RT La colaboraci n p blico privada de los gobi...
# 8690  RT La colaboraci n p blico privada de los gobi...
# 8691  RT Para no perderse el seguimiento que est hac...
# 8692  RT La colaboraci n p blico privada de los gobi...
#
# [150 rows x 5 columns]

# %%
df_today = data_today_clean_tweet.copy()

# %%
from transformers import pipeline

# %%
classifier = pipeline('sentiment-analysis')

# %%
from transformers import AutoTokenizer, AutoModelForMaskedLM
tokenizer = AutoTokenizer.from_pretrained("dccuchile/bert-base-spanish-wwm-cased")
model = AutoModelForMaskedLM.from_pretrained("dccuchile/bert-base-spanish-wwm-cased")
# Out:
# Some weights of BertForMaskedLM were not initialized from the model checkpoint at dccuchile/bert-base-spanish-wwm-cased and are newly initialized: ['cls.predictions.decoder.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
def transform (x):
    return classifier(x)
# Apply transform function to all tweets 
df_today['sentiment'] = data_today_clean_tweet['tweets_clean'].apply(transform)

# %%
df_today
# Out:
#                     date                   id  \
# 8543 2020-10-23 00:02:23  1319428924116434944
# 8544 2020-10-23 00:11:28  1319431206086332419
# 8545 2020-10-23 00:13:54  1319431821067694082
# 8546 2020-10-23 01:03:15  1319444240099934208
# 8547 2020-10-23 02:26:26  1319465173086818305
# ...                  ...                  ...
# 8688 2020-10-23 11:29:32  1319601848693739520
# 8689 2020-10-23 11:31:01  1319602221357596675
# 8690 2020-10-23 11:31:22  1319602309316382721
# 8691 2020-10-23 11:32:20  1319602554146357251
# 8692 2020-10-23 11:44:42  1319605665401360385
#
#                                                    text  \
# 8543  RT @Esther_Gomez_M: Parece que @EMTmadrid pref...
# 8544  RT @edugaresp: El servicio de alquiler de bici...
# 8545  RT @Esther_Gomez_M: Prometió @AlmeidaPP_ 50 nu...
# 8546  RT @Esther_Gomez_M: Para conocer la difícil si...
# 8547  RT @Rita_Maestre: La foto que resume lo que ha...
# ...                                                 ...
# 8688  RT @PlataformaEMT: Buenos días plataformer@s.\...
# 8689  RT @PlataformaEMT: La colaboración público pri...
# 8690  RT @PlataformaEMT: La colaboración público pri...
# 8691  RT @verdechamberi: Para no perderse el seguimi...
# 8692  RT @PlataformaEMT: La colaboración público pri...
#
#                     user_name  \
# 8543     Ana Moradillo Alonso
# 8544  antonio 🏳️‍🌈antonio MAD
# 8545                     Kike
# 8546                    Rober
# 8547            Dani Aparicio
# ...                       ...
# 8688      Plataforma Sindical
# 8689               Marcos_HTZ
# 8690                      Jbp
# 8691            Gonzalo Lopez
# 8692              Trotamundos
#
#                                            tweets_clean  \
# 8543  RT Gomez M Parece que prefiere usar bicicletas...
# 8544  RT El servicio de alquiler de bicicletas de Ma...
# 8545  RT Gomez M Prometi 50 nuevas estaciones de est...
# 8546  RT Gomez M Para conocer la dif cil situaci n d...
# 8547  RT Maestre La foto que resume lo que ha hecho ...
# ...                                                 ...
# 8688  RT Buenos d as plataformer y contin an infland...
# 8689  RT La colaboraci n p blico privada de los gobi...
# 8690  RT La colaboraci n p blico privada de los gobi...
# 8691  RT Para no perderse el seguimiento que est hac...
# 8692  RT La colaboraci n p blico privada de los gobi...
#
#                                               sentiment  \
# 8543  [{'label': 'NEGATIVE', 'score': 0.940226495265...
# 8544  [{'label': 'NEGATIVE', 'score': 0.556998789310...
# 8545  [{'label': 'NEGATIVE', 'score': 0.915848910808...
# 8546  [{'label': 'NEGATIVE', 'score': 0.977445721626...
# 8547  [{'label': 'NEGATIVE', 'score': 0.944254934787...
# ...                                                 ...
# 8688  [{'label': 'NEGATIVE', 'score': 0.930744111537...
# 8689  [{'label': 'NEGATIVE', 'score': 0.982082843780...
# 8690  [{'label': 'NEGATIVE', 'score': 0.982082843780...
# 8691  [{'label': 'NEGATIVE', 'score': 0.794018328189...
# 8692  [{'label': 'NEGATIVE', 'score': 0.982082843780...
#
#                                             score  \
# 8543  <generator object <genexpr> at 0x1449eb0c0>
# 8544  <generator object <genexpr> at 0x1449eb0c0>
# 8545  <generator object <genexpr> at 0x1449eb0c0>
# 8546  <generator object <genexpr> at 0x1449eb0c0>
# 8547  <generator object <genexpr> at 0x1449eb0c0>
# ...                                           ...
# 8688  <generator object <genexpr> at 0x1449eb0c0>
# 8689  <generator object <genexpr> at 0x1449eb0c0>
# 8690  <generator object <genexpr> at 0x1449eb0c0>
# 8691  <generator object <genexpr> at 0x1449eb0c0>
# 8692  <generator object <genexpr> at 0x1449eb0c0>
#
#                                             label  \
# 8543  <generator object <genexpr> at 0x1449eb2a0>
# 8544  <generator object <genexpr> at 0x1449eb2a0>
# 8545  <generator object <genexpr> at 0x1449eb2a0>
# 8546  <generator object <genexpr> at 0x1449eb2a0>
# 8547  <generator object <genexpr> at 0x1449eb2a0>
# ...                                           ...
# 8688  <generator object <genexpr> at 0x1449eb2a0>
# 8689  <generator object <genexpr> at 0x1449eb2a0>
# 8690  <generator object <genexpr> at 0x1449eb2a0>
# 8691  <generator object <genexpr> at 0x1449eb2a0>
# 8692  <generator object <genexpr> at 0x1449eb2a0>
#
#                                              sentiment2
# 8543  [[{'label': 'NEGATIVE',  'score': 0.9402264952...
# 8544  [[{'label': 'NEGATIVE',  'score': 0.5569987893...
# 8545  [[{'label': 'NEGATIVE',  'score': 0.9158489108...
# 8546  [[{'label': 'NEGATIVE',  'score': 0.9774457216...
# 8547  [[{'label': 'NEGATIVE',  'score': 0.9442549347...
# ...                                                 ...
# 8688  [[{'label': 'NEGATIVE',  'score': 0.9307441115...
# 8689  [[{'label': 'NEGATIVE',  'score': 0.9820828437...
# 8690  [[{'label': 'NEGATIVE',  'score': 0.9820828437...
# 8691  [[{'label': 'NEGATIVE',  'score': 0.7940183281...
# 8692  [[{'label': 'NEGATIVE',  'score': 0.9820828437...
#
# [150 rows x 9 columns]

# %%
df_today['sentiment'] = df_today.sentiment.apply(str)

# %%
df_today['sentiment2'] = df_today['sentiment'].str.split(',')

# %%
df_today['sentiment2']
# Out:
# 8543    [[{'label': 'NEGATIVE',  'score': 0.9402264952...
# 8544    [[{'label': 'NEGATIVE',  'score': 0.5569987893...
# 8545    [[{'label': 'NEGATIVE',  'score': 0.9158489108...
# 8546    [[{'label': 'NEGATIVE',  'score': 0.9774457216...
# 8547    [[{'label': 'NEGATIVE',  'score': 0.9442549347...
#                               ...
# 8688    [[{'label': 'NEGATIVE',  'score': 0.9307441115...
# 8689    [[{'label': 'NEGATIVE',  'score': 0.9820828437...
# 8690    [[{'label': 'NEGATIVE',  'score': 0.9820828437...
# 8691    [[{'label': 'NEGATIVE',  'score': 0.7940183281...
# 8692    [[{'label': 'NEGATIVE',  'score': 0.9820828437...
# Name: sentiment2, Length: 150, dtype: object

# %%
print(re.split('XXX|YYY|ZZZ', df_today.sentiment))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-288-ddfddf52c664> in <module>
# ----> 1 print(re.split('XXX|YYY|ZZZ', df_today.sentiment))
#
# /Applications/anaconda3/envs/ironhack/lib/python3.7/re.py in split(pattern, string, maxsplit, flags)
#     211     and the remainder of the string is returned as the final element
#     212     of the list."""
# --> 213     return _compile(pattern, flags).split(string, maxsplit)
#     214
#     215 def findall(pattern, string, flags=0):
#
# TypeError: expected string or bytes-like object

# %%
df_today["score"] = (df_today["sentiment"][i][0]['score'] for i in range(df_today.shape[0]))

# %%
df_today
# Out:
#                     date                   id  \
# 8543 2020-10-23 00:02:23  1319428924116434944
# 8544 2020-10-23 00:11:28  1319431206086332419
# 8545 2020-10-23 00:13:54  1319431821067694082
# 8546 2020-10-23 01:03:15  1319444240099934208
# 8547 2020-10-23 02:26:26  1319465173086818305
# ...                  ...                  ...
# 8688 2020-10-23 11:29:32  1319601848693739520
# 8689 2020-10-23 11:31:01  1319602221357596675
# 8690 2020-10-23 11:31:22  1319602309316382721
# 8691 2020-10-23 11:32:20  1319602554146357251
# 8692 2020-10-23 11:44:42  1319605665401360385
#
#                                                    text  \
# 8543  RT @Esther_Gomez_M: Parece que @EMTmadrid pref...
# 8544  RT @edugaresp: El servicio de alquiler de bici...
# 8545  RT @Esther_Gomez_M: Prometió @AlmeidaPP_ 50 nu...
# 8546  RT @Esther_Gomez_M: Para conocer la difícil si...
# 8547  RT @Rita_Maestre: La foto que resume lo que ha...
# ...                                                 ...
# 8688  RT @PlataformaEMT: Buenos días plataformer@s.\...
# 8689  RT @PlataformaEMT: La colaboración público pri...
# 8690  RT @PlataformaEMT: La colaboración público pri...
# 8691  RT @verdechamberi: Para no perderse el seguimi...
# 8692  RT @PlataformaEMT: La colaboración público pri...
#
#                     user_name  \
# 8543     Ana Moradillo Alonso
# 8544  antonio 🏳️‍🌈antonio MAD
# 8545                     Kike
# 8546                    Rober
# 8547            Dani Aparicio
# ...                       ...
# 8688      Plataforma Sindical
# 8689               Marcos_HTZ
# 8690                      Jbp
# 8691            Gonzalo Lopez
# 8692              Trotamundos
#
#                                            tweets_clean  \
# 8543  RT Gomez M Parece que prefiere usar bicicletas...
# 8544  RT El servicio de alquiler de bicicletas de Ma...
# 8545  RT Gomez M Prometi 50 nuevas estaciones de est...
# 8546  RT Gomez M Para conocer la dif cil situaci n d...
# 8547  RT Maestre La foto que resume lo que ha hecho ...
# ...                                                 ...
# 8688  RT Buenos d as plataformer y contin an infland...
# 8689  RT La colaboraci n p blico privada de los gobi...
# 8690  RT La colaboraci n p blico privada de los gobi...
# 8691  RT Para no perderse el seguimiento que est hac...
# 8692  RT La colaboraci n p blico privada de los gobi...
#
#                                               sentiment  \
# 8543  [{'label': 'NEGATIVE', 'score': 0.940226495265...
# 8544  [{'label': 'NEGATIVE', 'score': 0.556998789310...
# 8545  [{'label': 'NEGATIVE', 'score': 0.915848910808...
# 8546  [{'label': 'NEGATIVE', 'score': 0.977445721626...
# 8547  [{'label': 'NEGATIVE', 'score': 0.944254934787...
# ...                                                 ...
# 8688  [{'label': 'NEGATIVE', 'score': 0.930744111537...
# 8689  [{'label': 'NEGATIVE', 'score': 0.982082843780...
# 8690  [{'label': 'NEGATIVE', 'score': 0.982082843780...
# 8691  [{'label': 'NEGATIVE', 'score': 0.794018328189...
# 8692  [{'label': 'NEGATIVE', 'score': 0.982082843780...
#
#                                             score
# 8543  <generator object <genexpr> at 0x1449eb0c0>
# 8544  <generator object <genexpr> at 0x1449eb0c0>
# 8545  <generator object <genexpr> at 0x1449eb0c0>
# 8546  <generator object <genexpr> at 0x1449eb0c0>
# 8547  <generator object <genexpr> at 0x1449eb0c0>
# ...                                           ...
# 8688  <generator object <genexpr> at 0x1449eb0c0>
# 8689  <generator object <genexpr> at 0x1449eb0c0>
# 8690  <generator object <genexpr> at 0x1449eb0c0>
# 8691  <generator object <genexpr> at 0x1449eb0c0>
# 8692  <generator object <genexpr> at 0x1449eb0c0>
#
# [150 rows x 7 columns]

# %%
df_today["label"] = (df_today["sentiment"][i][0]['label'] for i in range(df_today.shape[0]))

# %%
df_today
# Out:
#                     date                   id  \
# 8543 2020-10-23 00:02:23  1319428924116434944
# 8544 2020-10-23 00:11:28  1319431206086332419
# 8545 2020-10-23 00:13:54  1319431821067694082
# 8546 2020-10-23 01:03:15  1319444240099934208
# 8547 2020-10-23 02:26:26  1319465173086818305
# ...                  ...                  ...
# 8688 2020-10-23 11:29:32  1319601848693739520
# 8689 2020-10-23 11:31:01  1319602221357596675
# 8690 2020-10-23 11:31:22  1319602309316382721
# 8691 2020-10-23 11:32:20  1319602554146357251
# 8692 2020-10-23 11:44:42  1319605665401360385
#
#                                                    text  \
# 8543  RT @Esther_Gomez_M: Parece que @EMTmadrid pref...
# 8544  RT @edugaresp: El servicio de alquiler de bici...
# 8545  RT @Esther_Gomez_M: Prometió @AlmeidaPP_ 50 nu...
# 8546  RT @Esther_Gomez_M: Para conocer la difícil si...
# 8547  RT @Rita_Maestre: La foto que resume lo que ha...
# ...                                                 ...
# 8688  RT @PlataformaEMT: Buenos días plataformer@s.\...
# 8689  RT @PlataformaEMT: La colaboración público pri...
# 8690  RT @PlataformaEMT: La colaboración público pri...
# 8691  RT @verdechamberi: Para no perderse el seguimi...
# 8692  RT @PlataformaEMT: La colaboración público pri...
#
#                     user_name  \
# 8543     Ana Moradillo Alonso
# 8544  antonio 🏳️‍🌈antonio MAD
# 8545                     Kike
# 8546                    Rober
# 8547            Dani Aparicio
# ...                       ...
# 8688      Plataforma Sindical
# 8689               Marcos_HTZ
# 8690                      Jbp
# 8691            Gonzalo Lopez
# 8692              Trotamundos
#
#                                            tweets_clean  \
# 8543  RT Gomez M Parece que prefiere usar bicicletas...
# 8544  RT El servicio de alquiler de bicicletas de Ma...
# 8545  RT Gomez M Prometi 50 nuevas estaciones de est...
# 8546  RT Gomez M Para conocer la dif cil situaci n d...
# 8547  RT Maestre La foto que resume lo que ha hecho ...
# ...                                                 ...
# 8688  RT Buenos d as plataformer y contin an infland...
# 8689  RT La colaboraci n p blico privada de los gobi...
# 8690  RT La colaboraci n p blico privada de los gobi...
# 8691  RT Para no perderse el seguimiento que est hac...
# 8692  RT La colaboraci n p blico privada de los gobi...
#
#                                               sentiment  \
# 8543  [{'label': 'NEGATIVE', 'score': 0.940226495265...
# 8544  [{'label': 'NEGATIVE', 'score': 0.556998789310...
# 8545  [{'label': 'NEGATIVE', 'score': 0.915848910808...
# 8546  [{'label': 'NEGATIVE', 'score': 0.977445721626...
# 8547  [{'label': 'NEGATIVE', 'score': 0.944254934787...
# ...                                                 ...
# 8688  [{'label': 'NEGATIVE', 'score': 0.930744111537...
# 8689  [{'label': 'NEGATIVE', 'score': 0.982082843780...
# 8690  [{'label': 'NEGATIVE', 'score': 0.982082843780...
# 8691  [{'label': 'NEGATIVE', 'score': 0.794018328189...
# 8692  [{'label': 'NEGATIVE', 'score': 0.982082843780...
#
#                                             score  \
# 8543  <generator object <genexpr> at 0x1449eb0c0>
# 8544  <generator object <genexpr> at 0x1449eb0c0>
# 8545  <generator object <genexpr> at 0x1449eb0c0>
# 8546  <generator object <genexpr> at 0x1449eb0c0>
# 8547  <generator object <genexpr> at 0x1449eb0c0>
# ...                                           ...
# 8688  <generator object <genexpr> at 0x1449eb0c0>
# 8689  <generator object <genexpr> at 0x1449eb0c0>
# 8690  <generator object <genexpr> at 0x1449eb0c0>
# 8691  <generator object <genexpr> at 0x1449eb0c0>
# 8692  <generator object <genexpr> at 0x1449eb0c0>
#
#                                             label
# 8543  <generator object <genexpr> at 0x1449eb2a0>
# 8544  <generator object <genexpr> at 0x1449eb2a0>
# 8545  <generator object <genexpr> at 0x1449eb2a0>
# 8546  <generator object <genexpr> at 0x1449eb2a0>
# 8547  <generator object <genexpr> at 0x1449eb2a0>
# ...                                           ...
# 8688  <generator object <genexpr> at 0x1449eb2a0>
# 8689  <generator object <genexpr> at 0x1449eb2a0>
# 8690  <generator object <genexpr> at 0x1449eb2a0>
# 8691  <generator object <genexpr> at 0x1449eb2a0>
# 8692  <generator object <genexpr> at 0x1449eb2a0>
#
# [150 rows x 8 columns]

# %%
# Out:
#                  date                   id  \
# 0 2020-09-29 06:34:23  1310830261450539009
# 1 2020-09-29 07:01:33  1310837099189473280
# 2 2020-09-29 07:43:50  1310847740386201600
# 3 2020-09-29 07:53:20  1310850131344920576
# 4 2020-09-29 08:05:56  1310853301810888704
#
#                                                 text       user_name  \
# 0  RT @carnecrudaradio: Quiero felicitar al alcal...       alex vega
# 1  Señores de @BiciMAD @MADRID las bicis están mu...     Neuroneater
# 2  @JMDLatina Espero de este distrito no solo que...     Andrés Pina
# 3  RT @_AguilarM: @PlataformaEMT @BiciMAD @bcarab...  ElMaNDaLoRiaNo
# 4  La misma vergüenza de TODOS los días. Una esta...      Diego Azul
#
#                                         tweets_clean  \
# 0  RT Quiero felicitar al alcalde por su exitosa ...
# 1  Se ores de las bicis est n muy descuidadas lo ...
# 2  Espero de este distrito no solo que proteja el...
# 3  RT AguilarM O la fecha de la ltima OPE para Av...
# 4  La misma verg enza de TODOS los d as Una estac...
#
#                                            sentiment     score     label
# 0  [{'label': 'NEGATIVE', 'score': 0.985985696315...  0.985986  NEGATIVE
# 1  [{'label': 'NEGATIVE', 'score': 0.981788218021...  0.981788  NEGATIVE
# 2  [{'label': 'NEGATIVE', 'score': 0.980981051921...  0.980981  NEGATIVE
# 3  [{'label': 'NEGATIVE', 'score': 0.983189225196...  0.983189  NEGATIVE
# 4  [{'label': 'NEGATIVE', 'score': 0.994368195533...  0.994368  NEGATIVE

# %%
sum(data["label"] == "POSITIVE")
# Out:
# 637

# %%
sum(data["label"] == "NEGATIVE")
# Out:
# 8056

# %%
data['score'].mean()
# Out:
# 0.9242670292631058

# %%
score = data['score']

# %%
# series (watch the index)
positive = (data["label"] == "POSITIVE")

score[positive].mean()
# Out:
# 0.7425865419618376

# %%
# series (watch the index)
negative = (data["label"] == "NEGATIVE")

score[negative].mean()
# Out:
# 0.9386327778245391

# %%
data['label'].all()   # because one element is zero
# Out:
# 'NEGATIVE'

# %%
data['label'].any()   # because one (or more) elements are non-zero
# Out:
# 'NEGATIVE'

# %%
data.label == 'POSITIVE'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8688    False
# 8689    False
# 8690    False
# 8691    False
# 8692    False
# Name: label, Length: 8693, dtype: bool

# %%
data['label_coded'] = data['label'].apply(lambda x: 1 if x == 'POSITIVE' else -1)

# %%
data
# Out:
#                     date                   id  \
# 0    2020-09-29 06:34:23  1310830261450539009
# 1    2020-09-29 07:01:33  1310837099189473280
# 2    2020-09-29 07:43:50  1310847740386201600
# 3    2020-09-29 07:53:20  1310850131344920576
# 4    2020-09-29 08:05:56  1310853301810888704
# ...                  ...                  ...
# 8688 2020-10-23 11:29:32  1319601848693739520
# 8689 2020-10-23 11:31:01  1319602221357596675
# 8690 2020-10-23 11:31:22  1319602309316382721
# 8691 2020-10-23 11:32:20  1319602554146357251
# 8692 2020-10-23 11:44:42  1319605665401360385
#
#                                                    text            user_name  \
# 0     RT @carnecrudaradio: Quiero felicitar al alcal...            alex vega
# 1     Señores de @BiciMAD @MADRID las bicis están mu...          Neuroneater
# 2     @JMDLatina Espero de este distrito no solo que...          Andrés Pina
# 3     RT @_AguilarM: @PlataformaEMT @BiciMAD @bcarab...       ElMaNDaLoRiaNo
# 4     La misma vergüenza de TODOS los días. Una esta...           Diego Azul
# ...                                                 ...                  ...
# 8688  RT @PlataformaEMT: Buenos días plataformer@s.\...  Plataforma Sindical
# 8689  RT @PlataformaEMT: La colaboración público pri...           Marcos_HTZ
# 8690  RT @PlataformaEMT: La colaboración público pri...                  Jbp
# 8691  RT @verdechamberi: Para no perderse el seguimi...        Gonzalo Lopez
# 8692  RT @PlataformaEMT: La colaboración público pri...          Trotamundos
#
#                                            tweets_clean  \
# 0     RT Quiero felicitar al alcalde por su exitosa ...
# 1     Se ores de las bicis est n muy descuidadas lo ...
# 2     Espero de este distrito no solo que proteja el...
# 3     RT AguilarM O la fecha de la ltima OPE para Av...
# 4     La misma verg enza de TODOS los d as Una estac...
# ...                                                 ...
# 8688  RT Buenos d as plataformer y contin an infland...
# 8689  RT La colaboraci n p blico privada de los gobi...
# 8690  RT La colaboraci n p blico privada de los gobi...
# 8691  RT Para no perderse el seguimiento que est hac...
# 8692  RT La colaboraci n p blico privada de los gobi...
#
#                                               sentiment     score     label  \
# 0     [{'label': 'NEGATIVE', 'score': 0.985985696315...  0.985986  NEGATIVE
# 1     [{'label': 'NEGATIVE', 'score': 0.981788218021...  0.981788  NEGATIVE
# 2     [{'label': 'NEGATIVE', 'score': 0.980981051921...  0.980981  NEGATIVE
# 3     [{'label': 'NEGATIVE', 'score': 0.983189225196...  0.983189  NEGATIVE
# 4     [{'label': 'NEGATIVE', 'score': 0.994368195533...  0.994368  NEGATIVE
# ...                                                 ...       ...       ...
# 8688  [{'label': 'NEGATIVE', 'score': 0.930744111537...  0.930744  NEGATIVE
# 8689  [{'label': 'NEGATIVE', 'score': 0.982082843780...  0.982083  NEGATIVE
# 8690  [{'label': 'NEGATIVE', 'score': 0.982082843780...  0.982083  NEGATIVE
# 8691  [{'label': 'NEGATIVE', 'score': 0.794018328189...  0.794018  NEGATIVE
# 8692  [{'label': 'NEGATIVE', 'score': 0.982082843780...  0.982083  NEGATIVE
#
#       label_coded
# 0              -1
# 1              -1
# 2              -1
# 3              -1
# 4              -1
# ...           ...
# 8688           -1
# 8689           -1
# 8690           -1
# 8691           -1
# 8692           -1
#
# [8693 rows x 9 columns]

# %%
data['score_coded'] = data['label_coded'] * data['score']

# %%
data
# Out:
#                     date                   id  \
# 0    2020-09-29 06:34:23  1310830261450539009
# 1    2020-09-29 07:01:33  1310837099189473280
# 2    2020-09-29 07:43:50  1310847740386201600
# 3    2020-09-29 07:53:20  1310850131344920576
# 4    2020-09-29 08:05:56  1310853301810888704
# ...                  ...                  ...
# 8688 2020-10-23 11:29:32  1319601848693739520
# 8689 2020-10-23 11:31:01  1319602221357596675
# 8690 2020-10-23 11:31:22  1319602309316382721
# 8691 2020-10-23 11:32:20  1319602554146357251
# 8692 2020-10-23 11:44:42  1319605665401360385
#
#                                                    text            user_name  \
# 0     RT @carnecrudaradio: Quiero felicitar al alcal...            alex vega
# 1     Señores de @BiciMAD @MADRID las bicis están mu...          Neuroneater
# 2     @JMDLatina Espero de este distrito no solo que...          Andrés Pina
# 3     RT @_AguilarM: @PlataformaEMT @BiciMAD @bcarab...       ElMaNDaLoRiaNo
# 4     La misma vergüenza de TODOS los días. Una esta...           Diego Azul
# ...                                                 ...                  ...
# 8688  RT @PlataformaEMT: Buenos días plataformer@s.\...  Plataforma Sindical
# 8689  RT @PlataformaEMT: La colaboración público pri...           Marcos_HTZ
# 8690  RT @PlataformaEMT: La colaboración público pri...                  Jbp
# 8691  RT @verdechamberi: Para no perderse el seguimi...        Gonzalo Lopez
# 8692  RT @PlataformaEMT: La colaboración público pri...          Trotamundos
#
#                                            tweets_clean  \
# 0     RT Quiero felicitar al alcalde por su exitosa ...
# 1     Se ores de las bicis est n muy descuidadas lo ...
# 2     Espero de este distrito no solo que proteja el...
# 3     RT AguilarM O la fecha de la ltima OPE para Av...
# 4     La misma verg enza de TODOS los d as Una estac...
# ...                                                 ...
# 8688  RT Buenos d as plataformer y contin an infland...
# 8689  RT La colaboraci n p blico privada de los gobi...
# 8690  RT La colaboraci n p blico privada de los gobi...
# 8691  RT Para no perderse el seguimiento que est hac...
# 8692  RT La colaboraci n p blico privada de los gobi...
#
#                                               sentiment     score     label  \
# 0     [{'label': 'NEGATIVE', 'score': 0.985985696315...  0.985986  NEGATIVE
# 1     [{'label': 'NEGATIVE', 'score': 0.981788218021...  0.981788  NEGATIVE
# 2     [{'label': 'NEGATIVE', 'score': 0.980981051921...  0.980981  NEGATIVE
# 3     [{'label': 'NEGATIVE', 'score': 0.983189225196...  0.983189  NEGATIVE
# 4     [{'label': 'NEGATIVE', 'score': 0.994368195533...  0.994368  NEGATIVE
# ...                                                 ...       ...       ...
# 8688  [{'label': 'NEGATIVE', 'score': 0.930744111537...  0.930744  NEGATIVE
# 8689  [{'label': 'NEGATIVE', 'score': 0.982082843780...  0.982083  NEGATIVE
# 8690  [{'label': 'NEGATIVE', 'score': 0.982082843780...  0.982083  NEGATIVE
# 8691  [{'label': 'NEGATIVE', 'score': 0.794018328189...  0.794018  NEGATIVE
# 8692  [{'label': 'NEGATIVE', 'score': 0.982082843780...  0.982083  NEGATIVE
#
#       label_coded  score_coded
# 0              -1    -0.985986
# 1              -1    -0.981788
# 2              -1    -0.980981
# 3              -1    -0.983189
# 4              -1    -0.994368
# ...           ...          ...
# 8688           -1    -0.930744
# 8689           -1    -0.982083
# 8690           -1    -0.982083
# 8691           -1    -0.794018
# 8692           -1    -0.982083
#
# [8693 rows x 10 columns]

# %%
data.to_csv('../data/results/data_sentiment.csv', index=False)

# %% [markdown]
# #### 3.3 Hypothesis testing
# <hr>

# %% [markdown]
# ##### 3.3.1 Separate tweets from today and before

# %%
# check new Tweets are in df
data.sort_values('date', ascending = False).head(10)
# Out:
#                     date                   id  \
# 8692 2020-10-23 11:44:42  1319605665401360385
# 8691 2020-10-23 11:32:20  1319602554146357251
# 8690 2020-10-23 11:31:22  1319602309316382721
# 8689 2020-10-23 11:31:01  1319602221357596675
# 8688 2020-10-23 11:29:32  1319601848693739520
# 8687 2020-10-23 11:28:27  1319601575778811904
# 8686 2020-10-23 11:28:19  1319601542501224448
# 8685 2020-10-23 11:28:08  1319601494841327616
# 8684 2020-10-23 11:27:12  1319601262975909893
# 8683 2020-10-23 11:26:57  1319601198765363200
#
#                                                    text            user_name  \
# 8692  RT @PlataformaEMT: La colaboración público pri...          Trotamundos
# 8691  RT @verdechamberi: Para no perderse el seguimi...        Gonzalo Lopez
# 8690  RT @PlataformaEMT: La colaboración público pri...                  Jbp
# 8689  RT @PlataformaEMT: La colaboración público pri...           Marcos_HTZ
# 8688  RT @PlataformaEMT: Buenos días plataformer@s.\...  Plataforma Sindical
# 8687  La colaboración público privada de los gobiern...  Plataforma Sindical
# 8686  RT @PlataformaEMT: Cientos de bicicletas de @B...                 Javi
# 8685  RT @PlataformaEMT: Buenos días plataformer@s.\...                 Javi
# 8684  RT @carmartinco: La 204 de nuevo, @BiciMAD sup...                 Javi
# 8683  RT @diego_rebollo: Esta es la realidad de @Bic...                 Javi
#
#                                            tweets_clean  \
# 8692  RT La colaboraci n p blico privada de los gobi...
# 8691  RT Para no perderse el seguimiento que est hac...
# 8690  RT La colaboraci n p blico privada de los gobi...
# 8689  RT La colaboraci n p blico privada de los gobi...
# 8688  RT Buenos d as plataformer y contin an infland...
# 8687  La colaboraci n p blico privada de los gobiern...
# 8686  RT Cientos de bicicletas de se amontonan en la...
# 8685  RT Buenos d as plataformer y contin an infland...
# 8684  RT La 204 de nuevo supongo que avisar is a red...
# 8683  RT rebollo Esta es la realidad de Estaciones a...
#
#                                               sentiment     score     label  \
# 8692  [{'label': 'NEGATIVE', 'score': 0.982082843780...  0.982083  NEGATIVE
# 8691  [{'label': 'NEGATIVE', 'score': 0.794018328189...  0.794018  NEGATIVE
# 8690  [{'label': 'NEGATIVE', 'score': 0.982082843780...  0.982083  NEGATIVE
# 8689  [{'label': 'NEGATIVE', 'score': 0.982082843780...  0.982083  NEGATIVE
# 8688  [{'label': 'NEGATIVE', 'score': 0.930744111537...  0.930744  NEGATIVE
# 8687  [{'label': 'NEGATIVE', 'score': 0.985178053379...  0.985178  NEGATIVE
# 8686  [{'label': 'NEGATIVE', 'score': 0.880333662033...  0.880334  NEGATIVE
# 8685  [{'label': 'NEGATIVE', 'score': 0.930744111537...  0.930744  NEGATIVE
# 8684  [{'label': 'NEGATIVE', 'score': 0.979150831699...  0.979151  NEGATIVE
# 8683  [{'label': 'NEGATIVE', 'score': 0.983878135681...  0.983878  NEGATIVE
#
#       label_coded  score_coded
# 8692           -1    -0.982083
# 8691           -1    -0.794018
# 8690           -1    -0.982083
# 8689           -1    -0.982083
# 8688           -1    -0.930744
# 8687           -1    -0.985178
# 8686           -1    -0.880334
# 8685           -1    -0.930744
# 8684           -1    -0.979151
# 8683           -1    -0.983878

# %% [markdown]
# ##### 3.3.2 Code 'negative' and 'postive' with 0 and 1

# %%
# series (watch the index)
negative = (data["label"] == "NEGATIVE")

data_past[negative]['score_coded'].mean()
# Out:
# /Applications/anaconda3/envs/ironhack/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# -0.9390167360510748

# %%
data_today[negative]['score_coded'].mean()
# Out:
# /Applications/anaconda3/envs/ironhack/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# -0.9178306574690832

# %%
api.update_status(f'this is a comment', tweet_id)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-63-722437bdaf43> in <module>
# ----> 1 api.update_status(f'this is a comment', tweet_id)
#
# NameError: name 'api' is not defined
